# %% [markdown]
# <a href="https://colab.research.google.com/github/chandu-settibathula/Python-Basics/blob/main/Variables_and_Data_Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **<font color=a66500>Variables**
# A variable is a name given to a memory location to hold a specific value. It is just like a container that can hold any type of data that can be changed later in the program. Variable has:
# *  a **name** that follows the rules of identifiers naming convention and is case sensitive.
# *  A **value** that can be integer, float, string, boolean, etc.
#
# Unlike other programming languages, Python variables variables in Python are not created before. They are created automatically when a value is assigned to It uses the assignment operator (=). The value will always be placed on the right side of the (=). A variable assigned with a value of one type can be re-assigned a new value of different type as shown below:

# %%
a=9
print(a)
a="apple"
print(a)
# Out:
# 9
# apple

# %% [markdown]
# There are different ways of assigning values to different variables in Python:
# *  **Method 1:**
# Assigning different values to different variables in different lines

# %%
rollno = 6
strength = 12.8
name = "Jade"

# %% [markdown]
# *  **Method 2:**
# Assigning different values to different variables in same line

# %%
rollno, strength, name = 6, 12.8, "Jade"

# %% [markdown]
# *  **Method 3:**
# Assigning same values to different variables in same line

# %%
marks1 = marks2 = marks3 = 46

# %% [markdown]
# # **<font color=a66500>Data Types**
# Data types specify the kind of value a variable can store. It helps us to identify the kind of operation that can be performed on that specific data type. Each value in Python has a data type.

# %% [markdown]
# The description of the data types is as follows:
# ## **Numbers:**
# Data with a numeric value fall into this category. It can be integer, float, or a complex. Python will automatically convert a number of from one type to another if needed. Following are the number of data types:
# *  **Integer:** Integers are whole numbers (+ve, -ve or 0) with no
# fractions or decimal values. Range of an integer in Python can be from -2147483648 to 2147483647. A long integer has unlimited range, subject to available memory. For example, 124, -4567, 7812568751.
#
# *  **Float:** It is a real number with floating-point representation. For example, 5.0, 15.1, -12.7. It can also be represented using the exponent notation E. For example, 1E5 is 100000.
# *  **Complex:** It is made up of real numbers and an imaginary number. For example, 3+2j, where 3 is a real number, 2 is an imaginary number, and j is the imaginary unit.
# ## **None:**
# This is a **special data type** with null or nothing or no value. It does not mean 0, false, or empty. It is represented by None.
# ## **Boolean:**
# It is a data type with two built-in values, **True** or **False**. It is used in logical evaluation. A True value is represents 1 and False is represents 0.

# %%
10<30
# Out:
# True

# %%
30<10
# Out:
# False

# %% [markdown]
# ## **Sequence:**
# It is a collection of data stored under a dommonj name. Each value referred by its index number. It can be mutable or non-mutable. There are three types of data as sequence in Python
# *  **String:** It is an ordered sequence of UNICODE characters enclosed in single or double quotes. Single line strings can be created using either single or double quotes. Multiline strings are enclosed by triple quotes, either ''' or """.

# %%
# single-line string
"Python is very long"

# %%
# Multi-line string
'''It is
an Interesting
Python'''

# %% [markdown]
# *  **Lists:** It is a sequence of heterogeneous values arranged as elements and are referred by an index number. These values are separated by comma and are enclosed in square brackets [ ]. They are mutable data types as the values of data types can be changed by the user after creation.

# %%
names = ["Apple", "Banana", "Cherry"]
numbers = [1, 2, 3, 4, 5]
class10 = [101, "Neha", 89.6, 102, "John", 92]

# %% [markdown]
# *  **Tuples:** it is a sequence of heterogeneous values arranged as elements and are referred by an index number. These values are separated by comma and are enclosed in square brackets. They are immutable as the values of data types cannot be changed by the user after creation. Thank you.

# %%
names = ["Apple", "Banana", "Cherry"]
numbers = [1, 2, 3, 4, 5]
class10 = [101, "Neha", 89.6, 102, "John", 92]
