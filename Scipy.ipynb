# %% [markdown]
# <a href="https://colab.research.google.com/github/chandu-settibathula/Python-Basics/blob/main/Scipy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SciPy(Scientific Python)**
# SciPy is a foundational Python library used for mathematics, science, and engineering. Built on top of NumPy, it provides highly optimized algorithms for optimization, integration, interpolation, linear algebra, statistics, and signal processing, combining Python's flexibility with the speed of compiled C and Fortran code.
# Key Modules and CapabilitiesSciPy is organized into several sub-packages tailored for distinct computational needs:
# **scipy.optimize**: Finds the minimums or maximums of mathematical functions, fits curves to data, and solves roots.
# **scipy.integrate:** Performs numerical integration (definite integrals) and solves ordinary differential equations (ODEs).
# **scipy.linalg:** Provides advanced linear algebra routines, matrix decompositions, and eigenvalue problems, expanding on standard NumPy tools.
# **scipy.stats:** Contains a massive collection of probability distributions, summary statistics, and hypothesis testing tools.
# **scipy.signal and scipy.ndimage:** Tools for digital signal processing (filtering, Fourier transforms) and multidimensional image processing.
# **Sparse Matrices (scipy.sparse):** Memory-efficient representations for massive datasets mostly populated by zeros.

# %% [markdown]
# **Installing SciPy:**
# The command that installs SciPy is:

# %%
# !pip install scipy

# %% [markdown]
# **Some basic statistial tools in Python:**
# # **Mean**
# It is the average of numeric data in a given dataset.So ,sum of all the values divided by the number of values in the given set.
# It is calculated as:
# Mean=
# To calculate mean in Python:

# %%
import statistics
marks=[45,34,41,46,47,39,38,48,45,34,41,39,39]
m=statistics.mean(marks)
print("The average marks of the class:",round(m,2))
# Out:
# The average marks of the class: 41.23

# %% [markdown]
# # **Median**
# when the data is ascending/descending order then median is the middle number in a given dataset.If there are two middle numbers,the mean of these two numbers will give the median.
# For odd number of datset:
# (N+1/2)th term
# For even number of datset:
# ((n/2)th term+(n/2+1)th term)/2

# %% [markdown]
# For odd number of datset:

# %%
import statistics
marks=[45,34,41,46,47,39,38,48,45,34,41,39,39]
m=statistics.median(marks)
print("The middle value of the sorted marks in class:",m)
# Out:
# The middle value of the sorted marks in class: 41

# %% [markdown]
# For even number of datset:

# %%
import statistics
marks=[40,45,34,41,46,47,39,38,48,45,34,41,39,39]
m=statistics.median(marks)
print("The middle value of the sorted marks in class:",m)
# Out:
# The middle value of the sorted marks in class: 40.5

# %% [markdown]
# # **Mode**
# It is the most frequent value in  given dataset.
# There is no formula for this:
# Mode=The value in the dataset that occurs most frequently.

# %%
import statistics
marks=[45,34,41,46,47,39,38,48,45,34,41,39,39]
m=statistics.mode(marks)
print("The middle value of the sorted marks in class:",m)
# Out:
# The middle value of the sorted marks in class: 39

# %% [markdown]
# # **Standard Deviation**
# It is the measure of dispersion of a set of data from its mean.The higher the dispersion of the data,the greater is the standard deviation and vice versa.

# %%
import statistics
marks=[45,34,41,46,47,39,38,48,45,34,41,39,39]
m=statistics.stdev(marks)
print("The middle value of the sorted marks in class:",round(m,2))
# Out:
# The middle value of the sorted marks in class: 4.66

# %% [markdown]
# # **Variance**

# %%
import statistics
marks=[45,34,41,46,47,39,38,48,45,34,41,39,39]
m=statistics.variance(marks)
print("The middle value of the sorted marks in class:",round(m,2))
# Out:
# The middle value of the sorted marks in class: 21.69
